# %%
from PyPDF2 import PdfReader
from PyPDF2 import PdfFileReader
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.text_splitter import CharacterTextSplitter
from langchain.vectorstores import FAISS

# %%
import os
os.environ["OPENAI_API_KEY"] = "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"

# %%
# provide the path of  pdf file/files.
pdfreader = PdfReader('C:/Users/Genesis/OneDrive/Desktop/Projects/RAG OpenAI Application/f91e4b8e-5c84-492f-889a-0e8fd41337c7/SynapseNotebook/78b6d6b0-9bb8-4b8b-87af-ea2a62f33837/Notebook 4/Kaggle_Terms_and_Condition.pdf')

# %%
from typing_extensions import Concatenate
# read text from pdf
raw_text = ''
for i, page in enumerate(pdfreader.pages):
    content = page.extract_text()
    if content:
        raw_text += content

raw_text
# Out:
# 'Terms\nPLEASE\nNOTE\nTHA T\nYOUR\nUSE\nOF\nAND\nACCESS\nTO\nOUR\nSER VICES\n(DEFINED\nBELOW)\nARE\nSUBJECT\nTO\nTHE\nFOLLOWING\nTERMS.\nIF\nYOU\nDO\nNOT\nAGREE\nTO\nALL\nOF\nTHE\nFOLLOWING,\nYOU\nMAY\nNOT\nUSE\nOR\nACCESS\nTHE\nSER VICES\nIN\nANY\nMANNER.\nTerms\nof\nUse\nEffective\nDate:\nFebruary\n16,\n2024\nWelcome\nto\nKaggle.\nPlease\nread\non\nto\nlearn\nthe\nrules\nand\nrestrictions\nthat\ngovern\nyour\nuse\nof\nour\nwebsite(s),\nproducts,\nservices\nand\napplications\n(the\n“Services”).\nIf\nyou\nhave\nany\nquestions,\ncomments,\nor\nconcerns\nregarding\nthese\nTerms\nor\nthe\nServices,\nplease\ncontact\nus\n.\nThese\nTerms\nof\nUse\n(the\n“Terms”)\nare\na\nbinding\ncontract\nbetween\nyou\nand\nKaggle\nInc.\n(“Kaggle,”\n“we”\nand\n“us”).\nKaggle\nis\norganized\nunder\nthe\nlaws\nof\nthe\nState\nof\nDelaware,\nUSA,\nand\nhas\noffices\nlocated\nat\n1600\nAmphitheatre\nParkway ,\nMountain\nView,\nCalifornia\n94043\nUSA.\nYou\nmust\nagree\nto\nand\naccept\nall\nof\nthe\nTerms,\n
# ...

# %%
# We need to split the text using Character Text Split such that it should not increse token size
text_splitter = CharacterTextSplitter(
    separator = "\n",
    chunk_size = 800,
    chunk_overlap  = 100,
    length_function = len,
)
texts = text_splitter.split_text(raw_text)

# %%
# Download embeddings from OpenAI
embeddings = OpenAIEmbeddings()
# Out:
# c:\Users\Genesis\AppData\Local\Programs\Python\Python310\lib\site-packages\langchain_core\_api\deprecation.py:117: LangChainDeprecationWarning: The class `langchain_community.embeddings.openai.OpenAIEmbeddings` was deprecated in langchain-community 0.1.0 and will be removed in 0.2.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import OpenAIEmbeddings`.
#   warn_deprecated(

# %%
document_search = FAISS.from_texts(texts, embeddings)
document_search

# %%
from langchain.chains.question_answering import load_qa_chain
from langchain.llms import OpenAI

chain = load_qa_chain(OpenAI(), chain_type="stuff")
# Out:
# c:\Users\Genesis\AppData\Local\Programs\Python\Python310\lib\site-packages\langchain_core\_api\deprecation.py:117: LangChainDeprecationWarning: The class `langchain_community.llms.openai.OpenAI` was deprecated in langchain-community 0.0.10 and will be removed in 0.2.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import OpenAI`.
#   warn_deprecated(

# %%
query =""
while(query != 'End'):    
    query = input("Enter your query or Write 'End' to Terminate:")
    if(query != 'End'):
        docs = document_search.similarity_search(query)
        answer = chain.run(input_documents=docs, question=query)
        print('Query: ', query)
        print('-------------------------------------------')
        print('Answer: ',answer)
    else:
        print('Terminated')
        break
# Out:
# c:\Users\Genesis\AppData\Local\Programs\Python\Python310\lib\site-packages\langchain_core\_api\deprecation.py:117: LangChainDeprecationWarning: The function `run` was deprecated in LangChain 0.1.0 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(
# Query:  What is the summary of the document
# -------------------------------------------
# Answer:   The document outlines the terms and conditions for using Kaggle's services, including the right to withdraw from the contract within 14 days for EEA-based consumers. These terms may change as the services continue to improve, and certain obligations and terms will continue even after termination of the contract.
# Terminated
